# %% [markdown]
# # History of Python
# - Python was developed by Guido Van Rossum in 1989 in The Netherlands.
# - Curent version is 3.0.
# - This launguage appropriate for Data Science, Data Visualization, Machine Learning, Web Development, Automation, Scientific Computing,...
# -

# %%
def num_to_string(n):
    return str(n)
num_to_string(456)
# Out:
# '456'

# %%
def string_to_num(s):
    return int(s)
string_to_num("123")
# Out:
# 123

# %% [markdown]
# # PROBLEM
# - String

# %%
# Problem: Henry March -> H.M
# string
def prime_name(name):
    #split name to parts
    parts = name.split()
    first = parts[0][0].upper()
    second = parts[1][0].upper()
    #/The `upper()` method in Python is used to convert all the characters in 
    # a string to uppercase(chữ hoa). In the context of your code snippet, 
    # `upper()` is being used to convert the first character of the first name to uppercase.
    print(first)
    print(second)
    print(first + "." + second)
#prime_name("huynh gia")

def abbrevName1(name):
    return '.'.join(w[0] for w in name.split()).upper()
#abbrevName1("huynh gia")

def abbrevName2(name):
    first, last = name.upper().split(' ')
    return first[0] + '.' + last[0]
#abbrevName2("huynh gia")

def abbrevName3(name):
    names = name.split()
    return f"{names[0][0]}.{names[1][0]}".upper()

def abbrevName4(name):
    return name.split(' ')[0][0].upper()+'.'+name.split(' ')[1][0].upper()
# Out:
# 'H.G'

# %%
# Problem: "45385593107843568" -> 01011110001100111 when <5 replace = '0', other replace = '1'
def fake_bin(x):
    #num = int(x) 
    #"45385593107843568" 
    new = x.split()
    #for i in x:
    print(new)
    #
#fake_bin("45")

def fake_bin1(s):
    return ''.join('1' if int(digit) >= 5 else '0' for digit in s)

def fake_bin2(x):
    output = []
    for digit in x:
        if digit < '5':
            output.append('0')
        else:
            output.append('1')
    return ''.join(output)# nối các thành phần lại thành một chuỗi 
#fake_bin2("45385593107843568")

def fake_bin3(x):
    return ''.join('0' if c < '5' else '1' for c in x)

def fake_bin4(x):
    result = ""
    for num in x:
        if int(num) < 5:
            result = result + "0"
        else:
            result = result + "1"
    return result
# Out:
# 0000111110

# %%
# Problem: Given an array of integers, return a new array with each value doubled. [1,2] -> [2,4]]]

def maps(a):
    return [2 * x for x in a]

def maps(a):
    num = []
    for i in a:
        num.append(i * 2)
    return num
def maps(a):
    for i in range(len(a)):
        a[i] = a[i] * 2
    return a
# Out:
# '01011110001100111'

# %%
# Problem : check x have in array A or not return True/ False. Array include number/ string 
# String 
# Array
def check(seq, elem):
    return elem in seq
check([1,2,3,"HAHAH"], 1)
# Out:
# True
